# %%
import advertools as adv

bbc_sitemap = adv.sitemap_to_df('https://www.upgrad.com/study-abroad/sitemap1.xml')
bbc_sitemap.head(10)
# Out:
# 2025-03-13 22:09:57,177 | INFO | sitemaps.py:623 | sitemap_to_df | Getting https://www.upgrad.com/study-abroad/sitemap1.xml
#                                                  loc  \
# 0               https://www.upgrad.com/study-abroad/
# 1      https://www.upgrad.com/study-abroad/about-us/
# 2       https://www.upgrad.com/study-abroad/enquiry/
# 3  https://www.upgrad.com/study-abroad/germany/ua...
# 4  https://www.upgrad.com/study-abroad/australia/...
# 5  https://www.upgrad.com/study-abroad/canada/ua-...
# 6  https://www.upgrad.com/study-abroad/ua-acceler...
# 7  https://www.upgrad.com/study-abroad/ua-acceler...
# 8  https://www.upgrad.com/study-abroad/germany/ua...
# 9  https://www.upgrad.com/study-abroad/canada/ua-...
#
#                     lastmod changefreq  priority  \
# 0 2025-03-13 00:00:00+00:00      daily       1.0
# 1 2025-03-13 00:00:00+00:00      daily       1.0
# 2 2025-03-13 00:00:00+00:00      daily       1.0
# 3 2025-03-13 00:00:00+00:00      daily       1.0
# ...
